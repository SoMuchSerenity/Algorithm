# %% [markdown]
# ## Checkers With Peter Vincent and Minghao Zhong

# %% [markdown]
# To operate this notebook please select enter until the second python cell.
#
# We have had a consistent issue with the program becoming unresponsive. Unfortunately, we haven't been able to debug it. However, if you would like to check the functionality of the board we have created then you can use the different gameState's we have provided below. We would suggest beginning with gameState_1 until the program becomes unresponsive.

# %%
import math
from IPython.display import clear_output

gameState_1 = [[' ','X',' ','X',' ','X',' ','X'],
              ['X',' ','X',' ','X',' ','X',' '],
              [' ','X',' ','X',' ','X',' ','X'],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              ['O',' ','O',' ','O',' ','O',' '],       
              [' ','O',' ','O',' ','O',' ','O'],
              ['O',' ','O',' ','O',' ','O',' ']]

gameState_2 = [[' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ','X',' ','X',' ',' ',' '],
              [' ',' ',' ','O',' ',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ','O',' ',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],       
              [' ','O',' ','O',' ','O',' ','X'],
              [' ',' ',' ',' ',' ',' ',' ',' ']]

gameState_3 = [[' ',' ',' ',' ',' ','Q',' ',' '],
              [' ',' ','X',' ','X',' ','X',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ',' ','X',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ',' ','X',' ',' ',' '],       
              [' ','X',' ','O',' ','O',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' ']]

gameState_4 = [[' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ','X',' ',' ',' ','X',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],       
              [' ',' ',' ','O',' ','O',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' ']]

global draw_count
draw_count = 40 
PlayerTurn = 'O'
maxDepth = 2

def TestWhoWin(cur):
    countX,countO,checkernum_X,checkernum_O,checkernum_K,checkernum_Q = degreecheck(cur)
    global draw_count
    #If O cannot make any more moves then X wins
    if PlayerTurn == 'O' and countO == 0:
        print('X wins')
        return True
    #If X cannot make any more moves then O wins
    if PlayerTurn == 'X' and countX == 0:
        print('O wins')
        return True
    #If O has no more checkers then X wins
    if checkernum_O + checkernum_Q == 0:
        print('X wins')
        return True
    #If X has no more checkers then O wins
    if checkernum_X + checkernum_K == 0:
        print('O wins')
        return True
    #If there are over 40 moves without a piece being taken then it is a draw
    if draw_count == 0:
        print('Draw!')
        return True
    return False

def KingMe(cur):
    new_cur = cur.copy()
    #If there are any 'O' checkers on the top line then they will become a 'Q' (King)
    for i in range(len(new_cur[0])):
        if new_cur[0][i] == 'O':
            new_cur[0][i] = 'Q'
    #If there are any 'X' checkers on the bottom line then they will become a 'K' (King)
    for j in range(len(new_cur[7])):
        if new_cur[7][j] == 'X':
            new_cur[7][j] = 'K'
    return new_cur

def changePlayerTurn():
    global PlayerTurn
    if PlayerTurn == 'X':
        PlayerTurn = 'O'
    else:
        PlayerTurn = 'X'
        
        
def printGameBoard(cur):
    row_number = 0
# We have to clear the previous output
    clear_output()
# Some instructions to help our players
    print("Welcome to our checkers game!")
    print("Please use the row and column to select your checker and while placing your checker.")
    print("An X will change to a K and a O will turn to Q to represent a 'king' checker.")
    print("If you have made an incorrect selection you can escape using the 9 button.")
    print("Good luck!")
# We check after the player has moved if any checkers should be updated to a King
    cur = KingMe(cur)
# This helps players select row/column
    for i in cur:
        print(row_number,i)
        row_number += 1
    print('    0  ',' 1  ',' 2  ',' 3  ',' 4  ',' 5 ','  6  ',' 7')
    print("A player must make a leap in:", draw_count, "moves. Otherwise there will be a draw.")

    
def degreecheck(cur):
# This function is to understand if a player has any degrees of freedom. 
# This is used in our win condition as a player could have a checker on the board but not
# be able to move it, this indicates there are 0 degrees of freedom and is considered a loss. 
    countO = 0
    countX = 0
    checkernum_O = 0
    checkernum_X = 0
    checkernum_Q = 0
    checkernum_K = 0
    for i in range(8):
        for j in range(8):
            if cur[i][j] == 'X':
                checkernum_X += 1
                if i+1<=7 and j+1<=7 and cur[i+1][j+1] == ' ':
                    countX += 1
                if i+1<=7 and j-1>=0 and cur[i+1][j-1] == ' ':
                    countX += 1   
            elif cur[i][j] == 'O':
                checkernum_O += 1
                if i-1 >=0 and j+1 <=7 and cur[i-1][j+1] == ' ':
                    countO += 1
                if i-1 >=0 and j-1>=0 and cur[i-1][j-1] == ' ':
                    countO += 1
            elif cur[i][j] == 'K':
                checkernum_K += 1
                if 0<= i+1 <=7 and 0<= j+1 <=7 and cur[i+1][j+1] == ' ':
                    countX += 1    
                if 0<= i+1 <=7 and 0<= j-1 <=7 and cur[i+1][j-1] == ' ':
                    countX += 1
                if 0<= i-1 <=7 and 0<= j+1 <=7 and cur[i-1][j+1] == ' ':
                    countX += 1
                if 0<= i-1 <=7 and 0<= j-1 <=7 and cur[i-1][j-1] == ' ':
                    countX += 1
            elif cur[i][j] == 'Q':
                checkernum_Q += 1 
                if 0<= i+1 <=7 and 0<= j+1 <=7 and cur[i+1][j+1] == ' ':
                    countO += 1
                if 0<= i+1 <=7 and 0<= j-1 <=7 and cur[i+1][j-1] == ' ':
                    countO += 1
                if 0<= i-1 <=7 and 0<= j+1 <=7 and cur[i-1][j+1] == ' ':
                    countO += 1
                if 0<= i-1 <=7 and 0<= j-1 <=7 and cur[i-1][j-1] == ' ':
                    countO += 1    
    return countX, countO, checkernum_X, checkernum_O, checkernum_K, checkernum_Q
            
def degree(cur):
# We can use our degrees of freedome concept to understand the utility of nodes
# A checker is worth 5 and a king/queen is worth 10.
    countX, countO, checkernum_X, checkernum_O, checkernum_K, checkernum_Q = degreecheck(cur)
    return (countX - countO) + 5*(checkernum_X - checkernum_O) + 10*(checkernum_K - checkernum_Q)
    
def gotwoways(cur,i,j):
# This function makes a list of possible moves for each checker on the board
    global jumpState
    jumpState = []
# All moves for X
    if cur[i][j] == 'X':
        if 0 <= i + 2 <8 and 0<=j + 2 < 8 and cur[i + 2][j + 2] == ' ' and cur[i+1][j+1] in ('O','Q'):
            nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
            nextState[i+2][j+2] = 'X'
            nextState[i][j] = ' '
            nextState[i+1][j+1] = ' '
            gotwoways(nextState,i+2,j+2)
        if 0 <= i + 2 < 8 and 0 <=j - 2 < 8 and cur[i + 2][j - 2] == ' ' and cur[i+1][j-1] in ('O','Q'):
            nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
            nextState[i+2][j-2] = 'X'
            nextState[i][j] = ' '
            nextState[i+1][j-1] = ' '
            gotwoways(nextState,i+2,j-2)
        else:
            jumpState.append(cur)
    elif cur[i][j] == 'K':
# All moves for K
        if 0 <= i + 2 <8 and 0<=j + 2 < 8 and cur[i + 2][j + 2] == ' ' and cur[i+1][j+1] in ('O','Q'):
            nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
            nextState[i+2][j+2] = 'K'
            nextState[i][j] = ' '
            nextState[i+1][j+1] = ' '
            gotwoways(nextState,i+2,j+2)
        if 0 <= i + 2 < 8 and 0 <=j - 2 < 8 and cur[i + 2][j - 2] == ' ' and cur[i+1][j-1] in ('O','Q'):
            nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
            nextState[i+2][j-2] = 'K'
            nextState[i][j] = ' '
            nextState[i+1][j-1] = ' '
            gotwoways(nextState,i+2,j-2)
        if 0 <= i - 2 <8 and 0<=j + 2 < 8 and cur[i - 2][j + 2] == ' ' and cur[i-1][j+1] in ('O','Q'):
            nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
            nextState[i-2][j+2] = 'K'
            nextState[i][j] = ' '
            nextState[i-1][j+1] = ' '
            gotwoways(nextState,i-2,j+2)
        if 0 <= i - 2 < 8 and 0 <=j - 2 < 8 and cur[i - 2][j - 2] == ' ' and cur[i-1][j-1] in ('O','Q'):
            nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
            nextState[i-2][j-2] = 'K'
            nextState[i][j] = ' '
            nextState[i-1][j-1] = ' '
            gotwoways(nextState,i-2,j-2)
        else:
            jumpState.append(cur)           
    elif cur[i][j] == 'O':
# All moves for O
        if 0 <= i - 2 <8 and 0<=j + 2 < 8 and cur[i - 2][j + 2] == ' ' and cur[i-1][j+1] in ('K','X'):
            nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
            nextState[i-2][j+2] = 'O'
            nextState[i][j] = ' '
            nextState[i-1][j+1] = ' '
            gotwoways(nextState,i-2,j+2)
        if 0 <= i - 2 < 8 and 0 <=j - 2 < 8 and cur[i - 2][j - 2] == ' ' and cur[i-1][j-1] in ('K','X'):
            nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
            nextState[i-2][j-2] = 'O'
            nextState[i][j] = ' '
            nextState[i-1][j-1] = ' '
            gotwoways(nextState,i-2,j-2)    
        else:
            jumpState.append(cur)              
    elif cur[i][j] == 'Q':
# All moves for Q
        if 0 <= i - 2 <8 and 0<=j + 2 < 8 and cur[i - 2][j + 2] == ' ' and cur[i-1][j+1] in ('K','X'):
            nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
            nextState[i-2][j+2] = 'O'
            nextState[i][j] = ' '
            nextState[i-1][j+1] = ' '
            gotwoways(nextState,i-2,j+2)
        if 0 <= i - 2 < 8 and 0 <=j - 2 < 8 and cur[i - 2][j - 2] == ' ' and cur[i-1][j-1] in ('K','X'):
            nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
            nextState[i-2][j-2] = 'O'
            nextState[i][j] = ' '
            nextState[i-1][j-1] = ' '
            gotwoways(nextState,i-2,j-2)
        if 0 <= i + 2 <8 and 0<=j + 2 < 8 and cur[i + 2][j + 2] == ' ' and cur[i+1][j+1] in ('K','X'):
            nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
            nextState[i-2][j+2] = 'O'
            nextState[i][j] = ' '
            nextState[i-1][j+1] = ' '
            gotwoways(nextState,i-2,j+2)
        if 0 <= i + 2 < 8 and 0 <=j - 2 < 8 and cur[i + 2][j - 2] == ' ' and cur[i+1][j-1] in ('K','X'):
            nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
            nextState[i-2][j-2] = 'O'
            nextState[i][j] = ' '
            nextState[i-1][j-1] = ' '
            gotwoways(nextState,i-2,j-2)
        else:
            jumpState.append(cur)       
    return jumpState


def MinimaxDecision (cur):
# check the Max value for all possible actions
    maxVal = -math.inf
    alpha = -math.inf
    beta = math.inf
    global state
    state = 0
    global draw_count
    draw_count -= 1
    jumpState = []
    
    for i in range(8):
        for j in range(8):  
# check if we can make a leap (attacking move)           
            if ifleap(cur, i, j) and cur[i][j] in ('K','X'):
                gotwoways(cur, i, j)
                jumpState = gotwoways(cur,i,j)
    for a in jumpState:
        val = MinValue(a, alpha, beta, maxDepth)
        if (val > maxVal):
            maxVal = val
            state = [[a[ti][tj] for tj in range(8)] for ti in range(8)]
        if (val > alpha):
            alpha = val
    return state
# We can use our gotwoways function to understand the utility of nodes
    for i in range(8):
        for j in range(8):  
# check jump (non-attacking move)
            if (cur[i][j] == 'X') and ((0 <= i+1 < 8 and 0 <= j-1 < 8 and (cur[i+1][j-1] == ' ')) or (0 <= i+1 < 8 and 0 <=j+1 < 8 and cur[i+1][j+1] == ' ')):
# finding our Beta and V for X's moves
                if (0 <= i+1 < 8 and 0 <= j-1 < 8 and cur[i+1][j-1] == ' '):               
                    nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                    nextState[i+1][j-1] = 'X'
                    nextState[i][j] = ' '
                    val = MinValue(nextState, alpha, beta, maxDepth)
                    if (val > maxVal):
                        maxVal = val
                        state = [[nextState[ti][tj] for tj in range(8)] for ti in range(8)]
                    if (val > alpha):
                        alpha = val
                if (0 <= i+1 < 8 and 0 <=j+1 < 8 and cur[i+1][j+1] == ' '):  # it is a possible action                
                    nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                    nextState[i+1][j+1] = 'X'
                    nextState[i][j] = ' '
                    val = MinValue(nextState, alpha, beta, maxDepth) 
                    if (val > maxVal):
                        maxVal = val
                        state = [[nextState[ti][tj] for tj in range(8)] for ti in range(8)]
                    if (val > alpha):
                        alpha = val                   
                return state

def MaxValue (cur, alpha, beta, depth):
# we have 3 terminal states: X O Draw
    if TestWhoWin(cur) == 'X wins':
        return 100
    if TestWhoWin(cur) == 'O wins':
        return -100
    if TestWhoWin(cur) == 'Draw':
        return 0
    if (depth == 0):
        return degree(cur)
# check the Max value for all possible actions
    maxVal = -math.inf
    for i in range(8):
        for j in range(8):          
            if ifleap(cur, i, j):                    
                jumpState = gotwoways(cur,i,j)
                global draw_count
                draw_count = 40
    for a in jumpState:                         
        val = MinValue(a, alpha, beta, depth-1)  
        if (val > maxVal):
            maxVal = val
        if (val >= beta):
            return val
        if (val > alpha):
            alpha = val
    return maxVal
    for i in range(8):
        for j in range(8):
            if (cur[i][j] == 'X') and ((0 <= i+1 < 8 and 0 <= j-1 < 8 and cur[i+1][j-1] == ' ') or (0 <= i+1 < 8 and 0 <=j+1 < 8 and cur[i+1][j+1] == ' ')):
                if (0 <= i+1 < 8 and 0 <= j-1 < 8 and cur[i+1][j-1] == ' '):
                    nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                    nextState[i+1][j-1] = 'X'
                    nextState[i][j] = ' '
                    val = MinValue(nextState, alpha, beta, depth-1)
                    if (val > maxVal):
                        maxVal = val
                    if (val >= beta):
                        return val
                    if (val > alpha):
                        alpha = val
                if (0 <= i+1 < 8 and 0 <=j+1 < 8 and cur[i+1][j+1] == ' '):                
                    nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                    nextState[i+1][j+1] = 'X'
                    nextState[i][j] = ' '
                    val = MinValue(nextState, alpha, beta, depth-1)
                    if (val > maxVal):
                        maxVal = val
                    if (val >= beta):
                        return val
                    if (val > alpha):
                        alpha = val          
                return maxVal

def MinValue (cur, alpha, beta, depth):
  # we have 3 terminal states: X O Draw
    if TestWhoWin(cur) == 'X wins':
        return 100
    if TestWhoWin(cur) == 'O wins':
        return -100
    if TestWhoWin(cur) == 'Draw':
        return 0
    if (depth == 0):
        return degree(cur)
  # check the Max value for all possible actions
    minVal = math.inf 
    for i in range(8):
        for j in range(8):
            if ifleap(cur, i, j):                                                  
                jumpState = gotwoways(cur,i,j)
                global draw_count
                draw_count = 40
    for a in jumpState:
        val = MaxValue(a, alpha, beta, depth-1)
        if (val < minVal):
            minVal = val
        if (val <= alpha):
            return val
        if (val < beta):
            beta = val
    return minVal
    for i in range(8):
        for j in range(8):
            if cur[i][j] == 'O' and ((0 <= i-1 < 8 and 0 <=j-1 < 8 and cur[i-1][j-1] == ' ') or (0 <= i-1 < 8 and 0 <=j+1 < 8 and cur[i-1][j+1] == ' ')):                                       
                if (0 <= i-1 < 8 and 0 <=j-1 < 8 and cur[i-1][j-1] == ' '):
                    nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                    nextState[i-1][j-1] = 'O'
                    nextState[i][j] = ' '
                    val = MaxValue(nextState, alpha, beta, depth-1)                                           
                    if (val < minVal):
                        minVal = val
                    if (val <= alpha):
                        return val
                    if (val < beta):
                        beta = val           
                if (0 <= i-1 < 8 and 0 <=j+1 < 8 and cur[i-1][j+1] == ' '):                    
                    nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                    nextState[i-1][j+1] = 'O'
                    nextState[i][j] = ' '
                    val = MaxValue(nextState, alpha, beta, depth-1)
                    if (val < minVal):
                        minVal = val
                    if (val <= alpha):
                        return val
                    if (val < beta):
                        beta = val  
                return minVal

def ifleap(gameState, check_x, check_y):
    # if O leap X/K
    if gameState[check_x][check_y] == 'O':
        if ( 0<=check_x-2<=7 and 0<=check_y+2<=7 and gameState[check_x-1][check_y+1] in ('X','K') and gameState[check_x-2][check_y+2] == ' ') or (0<=check_x-2<=7 and 0<=check_y-2<=7 and gameState[check_x-1][check_y-1] in ('X','K') and gameState[check_x-2][check_y-2] == ' ') :
            return True
    # if Q leap X/K
    elif gameState[check_x][check_y] == 'Q': 
        if ( 0<=check_x-2<=7 and 0<=check_y+2<=7 and gameState[check_x-1][check_y+1] in ('X','K') and gameState[check_x-2][check_y+2] == ' ') or (0<=check_x-2<=7 and 0<=check_y-2<=7 and gameState[check_x-1][check_y-1] in ('X','K') and gameState[check_x-2][check_y-2] == ' ') or ( 0<=check_x+2<=7 and 0<=check_y-2<=7 and gameState[check_x+1][check_y-1] in ('X','K') and gameState[check_x+2][check_y-2] == ' ') or (0<=check_x+2<=7 and 0<=check_y+2<=7 and gameState[check_x+1][check_y+1] == ('X' in 'K') and gameState[check_x+2][check_y+2] == ' '):
            return True    
    # if X leap O/Q
    elif gameState[check_x][check_y] == 'X':
        if ( 0<=check_x+2<=7 and 0<=check_y-2<=7 and gameState[check_x+1][check_y-1] in ('O','Q') and gameState[check_x+2][check_y-2] == ' ') or (0<=check_x+2<=7 and 0<=check_y+2<=7 and gameState[check_x+1][check_y+1] in ('O','Q') and gameState[check_x+2][check_y+2] == ' '):
            return True
    # if K leap O/Q
    elif gameState[check_x][check_y] == 'K':
        if ( 0<=check_x-2<=7 and 0<=check_y+2<=7 and gameState[check_x-1][check_y+1] in ('O','Q') and gameState[check_x-2][check_y+2] == ' ') or (0<=check_x-2<=7 and 0<=check_y-2<=7 and gameState[check_x-1][check_y-1] in ('O','Q') and gameState[check_x-2][check_y-2] == ' ') or ( 0<=check_x+2<=7 and 0<=check_y-2<=7 and gameState[check_x+1][check_y-1] == ('O' or 'Q') and gameState[check_x+2][check_y-2] == ' ') or (0<=check_x+2<=7 and 0<=check_y+2<=7 and gameState[check_x+1][check_y+1] == ('O' or 'Q') and gameState[check_x+2][check_y+2] == ' '):
            return True
    return False
    
    
def input_info(gameState):
# This function handles the user's inputs. 
    check_x = int(input("Please provide the row number of the checker you would like to move: "))
    check_y = int(input("Please provide the column number of the checker you would like to move: "))
# This will handle errors until the user is provides a correct checker    
    while (check_x < 0 or check_x > 7 or check_y < 0 or check_y > 7 or gameState[check_x][check_y] not in ('O','Q')):
        check_x = int(input("Please provide a valid checker row number "))
        check_y = int(input("Please provide a valid checker column number "))
# We can give the user an escape by selecting 9 
    check_x_dir = int(input("Please provide the row number of where you would like to move: "))   
    if check_x_dir ==9:
        input_info(gameState)
    check_y_dir = int(input("Please provide the column number of where you would like to move: "))
    if check_y_dir ==9:
        input_info(gameState)
    while (gameState[check_x_dir][check_y_dir] != ' ') or ((abs(check_x_dir-check_x)!=1 or abs(check_y_dir-check_y)!=1) and ((abs(check_x_dir-check_x)!=2 or abs(check_y_dir-check_y)!=2))):
        check_x_dir = int(input("Please provide a valid row number "))
        if check_x_dir ==9:
            input_info(gameState)
        check_y_dir = int(input("Please provide  a valid column number "))
        if check_x_dir ==9:
            input_info(gameState)
    if ifleap(gameState,check_x,check_y):
        leap(gameState, check_x, check_y,check_x_dir, check_y_dir)
#We reset the draw_count after we have leap an enemy unit
        global draw_count
        draw_count = 40
    elif gameState[check_x_dir][check_y_dir] == ' ':
        draw_count -= 1
        if gameState[check_x][check_y] == 'O':
            gameState[check_x_dir][check_y_dir] = 'O'
            gameState[check_x][check_y] = ' '
        else:
            gameState[check_x_dir][check_y_dir] = 'Q'
            gameState[check_x][check_y] = ' '            
        return gameState

def leap(gameState, check_x, check_y,check_x_dir, check_y_dir):  
# Checkers allows for a second leap if the checker has leaped another checker
    gameState[(int((check_x + check_x_dir)/2))][int((check_y+check_y_dir)/2)] = ' '
    if gameState[check_x][check_y] in ('O', 'Q'):
        gameState[check_x_dir][check_y_dir] = gameState[check_x][check_y]
        gameState[check_x][check_y] = ' '
    printGameBoard(gameState)
# Checkers requires leaps to be taken therefore, if you can leap you must leap! 
    if ifleap(gameState, check_x_dir, check_y_dir):
        check_x = check_x_dir 
        check_y = check_y_dir 
        check_x_dir = int(input("Please provide the row number of where you would like to move: "))
        check_y_dir = int(input("Please provide the column number of where you would like to move: "))
        while ((check_x_dir < 0 or check_x_dir > 7 or check_y_dir < 0 or check_y_dir > 7) or gameState[check_x_dir][check_y_dir] != ' '):
            check_x_dir = int(input("Please provide a valid row number."))
            check_y_dir = int(input("Please provide a valid column number.")) 
# This will loop until the player is not leaping any more units
        leap(gameState, check_x, check_y, check_x_dir, check_y_dir)
    else: 
        return gameState

# %%
gameState = gameState_1

printGameBoard(gameState)

while(True):
    if (PlayerTurn == 'X'):
        printGameBoard(gameState)
        if (TestWhoWin(gameState)):
            break
        else:
            gameState = MinimaxDecision(gameState)
            changePlayerTurn()
    else:
        printGameBoard(gameState)
        if (TestWhoWin(gameState)):
            break
        else:
            gameState = MinimaxDecision(gameState)
            changePlayerTurn()
# Out:
# Welcome to our checkers game!
# Please use the row and column to select your checker and while placing your checker.
# An X will change to a K and a O will turn to Q to represent a 'king' checker.
# If you have made an incorrect selection you can escape using the 9 button.
# Good luck!
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# ~\AppData\Local\Temp/ipykernel_2580/2612711407.py in <module>
#      12             changePlayerTurn()
#      13     else:
# ---> 14         printGameBoard(gameState)
#      15         if (TestWhoWin(gameState)):
#      16             break
#
# ~\AppData\Local\Temp/ipykernel_2580/1489548209.py in printGameBoard(cur)
#      99     print("Good luck!")
#     100 # We check after the player has moved if any checkers should be updated to a King
# --> 101     cur = KingMe(cur)
#     102 # This helps players select row/column
#     103     for i in cur:
# ...

# %%
b

# %%
gameState_1 = [[' ','X',' ','X',' ','X',' ','X'],
              ['X',' ','X',' ','X',' ','X',' '],
              [' ','X',' ','X',' ','X',' ','X'],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              ['O',' ','O',' ','O',' ','O',' '],       
              [' ','O',' ','O',' ','O',' ','O'],
              ['O',' ','O',' ','O',' ','O',' ']]

gameState_2 = [[' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ','X',' ','X',' ',' ',' '],
              [' ',' ',' ','O',' ',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ','O',' ',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],       
              [' ','O',' ','O',' ','O',' ','X'],
              [' ',' ',' ',' ',' ',' ',' ',' ']]

gameState_3 = [[' ',' ',' ',' ',' ','Q',' ',' '],
              [' ',' ','X',' ','X',' ','X',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ',' ','X',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ',' ','X',' ',' ',' '],       
              [' ','X',' ','O',' ','O',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' ']]

gameState_4 = [[' ',' ',' ','X',' ',' ',' ',' '],
              [' ',' ','O',' ','O',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ','O',' ','O',' ','O',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ','O',' ','O',' ','O',' '],       
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' ']]

gameState_5 = [[' ',' ',' ','K',' ','X',' ',' '],
              [' ',' ','O',' ','O',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' '],       
              [' ',' ',' ',' ',' ',' ',' ',' '],
              [' ',' ',' ',' ',' ',' ',' ',' ']]

# %%
global jumpState
jumpState = []

# %%
for i in range(8):
    for j in range(8):
        if ifleap(gameState_5, i, j):
            print(len(gotwoways(gameState_5, i, j)))

# %%
gameState_5

# %%
def ifleap(gameState, check_x, check_y):
    # if O leap X/K
    if gameState[check_x][check_y] == 'O':
        if ( 0<=check_x-2<=7 and 0<=check_y+2<=7 and gameState[check_x-1][check_y+1] in ('X','K') and gameState[check_x-2][check_y+2] == ' ') or (0<=check_x-2<=7 and 0<=check_y-2<=7 and gameState[check_x-1][check_y-1] in ('X','K') and gameState[check_x-2][check_y-2] == ' ') :
            return True
    # if Q leap X/K
    elif gameState[check_x][check_y] == 'Q': 
        if ( 0<=check_x-2<=7 and 0<=check_y+2<=7 and gameState[check_x-1][check_y+1] in ('X','K') and gameState[check_x-2][check_y+2] == ' ') or (0<=check_x-2<=7 and 0<=check_y-2<=7 and gameState[check_x-1][check_y-1] in ('X','K') and gameState[check_x-2][check_y-2] == ' ') or ( 0<=check_x+2<=7 and 0<=check_y-2<=7 and gameState[check_x+1][check_y-1] in ('X','K') and gameState[check_x+2][check_y-2] == ' ') or (0<=check_x+2<=7 and 0<=check_y+2<=7 and gameState[check_x+1][check_y+1] == ('X' in 'K') and gameState[check_x+2][check_y+2] == ' '):
            return True    
    # if X leap O/Q
    elif gameState[check_x][check_y] == 'X':
        if ( 0<=check_x+2<=7 and 0<=check_y-2<=7 and gameState[check_x+1][check_y-1] in ('O','Q') and gameState[check_x+2][check_y-2] == ' ') or (0<=check_x+2<=7 and 0<=check_y+2<=7 and gameState[check_x+1][check_y+1] in ('O','Q') and gameState[check_x+2][check_y+2] == ' '):
            return True
    # if K leap O/Q
    elif gameState[check_x][check_y] == 'K':
        if ( 0<=check_x-2<=7 and 0<=check_y+2<=7 and gameState[check_x-1][check_y+1] in ('O','Q') and gameState[check_x-2][check_y+2] == ' ') or (0<=check_x-2<=7 and 0<=check_y-2<=7 and gameState[check_x-1][check_y-1] in ('O','Q') and gameState[check_x-2][check_y-2] == ' ') or ( 0<=check_x+2<=7 and 0<=check_y-2<=7 and gameState[check_x+1][check_y-1] == ('O' or 'Q') and gameState[check_x+2][check_y-2] == ' ') or (0<=check_x+2<=7 and 0<=check_y+2<=7 and gameState[check_x+1][check_y+1] == ('O' or 'Q') and gameState[check_x+2][check_y+2] == ' '):
            return True
    return False

# %%
jumpState = []
def gotwoways(cur,i,j):
    global jumpState

    # O - moves
    if cur[i][j] == 'O':
        if (0 <= i - 2 < 8 and 0 <=j + 2 < 8 and cur[i - 2][j + 2] == ' ' and cur[i-1][j+1] in ('X', 'K')) or (0 <= i - 2 < 8 and 0 <=j - 2 < 8 and cur[i - 2][j - 2] == ' ' and cur[i-1][j-1] in ('X', 'K')):

            if 0 <= i - 2 <8 and 0<=j + 2 < 8 and cur[i - 2][j + 2] == ' ' and cur[i-1][j+1] in ('X', 'K'):
                nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                nextState[i-2][j+2] = 'O'
                nextState[i][j] = ' '
                nextState[i-1][j+1] = ' '
                gotwoways(nextState,i-2,j+2)

            if 0 <= i - 2 < 8 and 0 <=j - 2 < 8 and cur[i - 2][j - 2] == ' ' and cur[i-1][j-1] in ('X', 'K'):
                nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                nextState[i-2][j-2] = 'O'
                nextState[i][j] = ' '
                nextState[i-1][j-1] = ' '
                gotwoways(nextState,i-2,j-2)
        else:
            jumpState.append(cur)

    # Q - moves
    if cur[i][j] == 'Q':
        if (0 <= i + 2 < 8 and 0 <= j + 2 < 8 and cur[i + 2][j + 2] == ' ' and cur[i+1][j+1] in ('X', 'K')) or (0 <= i + 2 < 8 and 0 <= j - 2 < 8 and cur[i + 2][j - 2] == ' ' and cur[i+1][j-1] in ('X', 'K')):

            if 0 <= i + 2 <8 and 0<=j + 2 < 8 and cur[i + 2][j + 2] == ' ' and cur[i+1][j+1] in ('X', 'K'):
                nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                nextState[i+2][j+2] = 'Q'
                nextState[i][j] = ' '
                nextState[i+1][j+1] = ' '
                gotwoways(nextState,i+2,j+2)

            if 0 <= i + 2 < 8 and 0 <=j - 2 < 8 and cur[i + 2][j - 2] == ' ' and cur[i+1][j-1] in ('X', 'K'):
                nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                nextState[i+2][j-2] = 'Q'
                nextState[i][j] = ' '
                nextState[i+1][j-1] = ' '
                gotwoways(nextState,i+2,j-2)
        else:
            jumpState.append(cur)

        if (0 <= i - 2 < 8 and 0 <=j + 2 < 8 and cur[i - 2][j + 2] == ' ' and cur[i-1][j+1] in ('X', 'K')) or (0 <= i - 2 < 8 and 0 <=j - 2 < 8 and cur[i - 2][j - 2] == ' ' and cur[i-1][j-1] in ('X', 'K')):

            if 0 <= i - 2 <8 and 0<=j + 2 < 8 and cur[i - 2][j + 2] == ' ' and cur[i-1][j+1] in ('X', 'K'):
                nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                nextState[i-2][j+2] = 'Q'
                nextState[i][j] = ' '
                nextState[i-1][j+1] = ' '
                gotwoways(nextState,i-2,j+2)

            if 0 <= i - 2 < 8 and 0 <=j - 2 < 8 and cur[i - 2][j - 2] == ' ' and cur[i-1][j-1] in ('X', 'K'):
                nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                nextState[i-2][j-2] = 'Q'
                nextState[i][j] = ' '
                nextState[i-1][j-1] = ' '
                gotwoways(nextState,i-2,j-2)
        else:
            jumpState.append(cur)

    # X - Moves
    if cur[i][j] == 'X':
        if (0 <= i + 2 < 8 and 0 <= j + 2 < 8 and cur[i + 2][j + 2] == ' ' and cur[i+1][j+1] in ('O', 'Q')) or (0 <= i + 2 < 8 and 0 <= j - 2 < 8 and cur[i + 2][j - 2] == ' ' and cur[i+1][j-1] in ('O', 'Q')):
            if 0 <= i + 2 <8 and 0<=j + 2 < 8 and cur[i + 2][j + 2] == ' ' and cur[i+1][j+1] in ('O', 'Q'):
                nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                nextState[i+2][j+2] = 'X'
                nextState[i][j] = ' '
                nextState[i+1][j+1] = ' '
                gotwoways(nextState,i+2,j+2)

            if 0 <= i + 2 < 8 and 0 <=j - 2 < 8 and cur[i + 2][j - 2] == ' ' and cur[i+1][j-1] in ('O', 'Q'):
                nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                nextState[i+2][j-2] = 'X'
                nextState[i][j] = ' '
                nextState[i+1][j-1] = ' '
                gotwoways(nextState,i+2,j-2)
        else:
            jumpState.append(cur)
    # K - Moves
    if cur[i][j] == 'K':
        if (0 <= i + 2 < 8 and 0 <= j + 2 < 8 and cur[i + 2][j + 2] == ' ' and cur[i+1][j+1] == 'O') or (0 <= i + 2 < 8 and 0 <= j - 2 < 8 and cur[i + 2][j - 2] == ' ' and cur[i+1][j-1] in ('O', 'Q')):

            if 0 <= i + 2 <8 and 0<=j + 2 < 8 and cur[i + 2][j + 2] == ' ' and cur[i+1][j+1] in ('O', 'Q'):
                nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                nextState[i+2][j+2] = 'K'
                nextState[i][j] = ' '
                nextState[i+1][j+1] = ' '
                gotwoways(nextState,i+2,j+2)

            if 0 <= i + 2 < 8 and 0 <=j - 2 < 8 and cur[i + 2][j - 2] == ' ' and cur[i+1][j-1] in ('O', 'Q'):
                nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                nextState[i+2][j-2] = 'K'
                nextState[i][j] = ' '
                nextState[i+1][j-1] = ' '
                gotwoways(nextState,i+2,j-2)
        else:
            jumpState.append(cur)
        if (0 <= i - 2 < 8 and 0 <=j + 2 < 8 and cur[i - 2][j + 2] == ' ' and cur[i-1][j+1] in ('O', 'Q')) or (0 <= i - 2 < 8 and 0 <=j - 2 < 8 and cur[i - 2][j - 2] == ' ' and cur[i-1][j-1] in ('O', 'Q')):

            if 0 <= i - 2 <8 and 0<=j + 2 < 8 and cur[i - 2][j + 2] == ' ' and cur[i-1][j+1] in ('O', 'Q'):
                nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                nextState[i-2][j+2] = 'K'
                nextState[i][j] = ' '
                nextState[i-1][j+1] = ' '
                gotwoways(nextState,i-2,j+2)

            if 0 <= i - 2 < 8 and 0 <=j - 2 < 8 and cur[i - 2][j - 2] == ' ' and cur[i-1][j-1] in ('O', 'Q'):
                nextState = [[cur[ti][tj] for tj in range(8)] for ti in range(8)]
                nextState[i-2][j-2] = 'K'
                nextState[i][j] = ' '
                nextState[i-1][j-1] = ' '
                gotwoways(nextState,i-2,j-2)
        else:
            jumpState.append(cur)
    return jumpState

# %%
jumpState = []
for i in range(8):
        for j in range(8):  
# check if we can make a leap (attacking move)           
            if ifleap(gameState_5, i, j) and gameState_5[i][j] == 'K': 
                jumpState.extend(gotwoways(gameState_5,i,j))
len(jumpState)

# %%
gameState_5

# %%
def remove_dup(x):
  return list(dict.fromkeys(x))

mylist = remove_dup(jumpState)

print(mylist)

# %%
for i in jumpState:
    for ii in i:
        new_jumpState = list(ii)
        
len(new_jumpState)

# %%
new_jumpState
